# %% [markdown]
# <a href="https://colab.research.google.com/github/GoreckiArtur/Zaawansowane-przetwarzanie-obrazu/blob/main/G%C3%B3recki_Artur_Praca_Dom04_ver02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Zadanie 1

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

# Generuje losowe punkty danych dla dwóch odcinków
x = np.random.rand(2, 2)
y = np.random.rand(2, 2)

# Rysuje odcinki między punktami danych
plt.plot(x[0], y[0], '-', label="foo")
plt.plot(x[1], y[1], '-', label="bar")

# Dodaje tytuł
plt.title("Dwa losowe odcinki 'foo' i 'bar'")

# Dodaje legendę
plt.legend()

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 2

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

# Generuje losowe punkty danych dla dwóch odcinków
x = np.random.rand(2, 2)
y = np.random.rand(2, 2)

# Rysuje odcinki między punktami danych - warto zauważyć, że brak zdefiniowanych labeli powoduje ostrzeżenie, zarazem tworząc pustą legendę
plt.plot(x[0], y[0], '-')
plt.plot(x[1], y[1], '-')

# Dodaje tytuł
plt.title("Dwa losowe odcinki ale bez swoich oznaczeń")

# Dodaje legendę
plt.legend()

plt.show()  # Wyświetla wykres
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Zadanie 3

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(2)  # Tworzy wektor od 0 do 1

# Rysuje linie
plt.plot(x, x, label="Niebieski")
plt.plot(x, 2*x)
plt.plot(x, 3*x, label="Zielony")

# Tworzy legendę
plt.legend(loc="upper right")



# Dodaje tytuł
plt.title("Odcinek zielony i niebieski, brakuje pomarańczowego")

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 4

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(1, 11)  # Wektor od 1 do 10
y1 = x
y2 = np.flip(x)  # Odwraca wektor

# Rysuje dwie linie
plt.plot(x, y1, label="Niebieska")
plt.plot(x, y2, label="Pomarańczowa")

# Dodaje tytuł
plt.title("Funkcja rosnąca jest niebieska, malejąca jest poamarańczowa")

# Tworzy legendę położoną na wschód
plt.legend( loc="right")

# Ukrywa legendę i ponownie ją pokazuje, aby dopasować rozmiar osi
plt.legend().set_visible(False)
plt.legend().set_visible(True)

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 5

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(1, 11)  # Wektor od 1 do 10
y1 = x
y2 = np.flip(x)  # Odwraca wektor

# Rysuje dwie linie
plt.plot(x, y1, label="Niebieska")
plt.plot(x, y2, label="Pomarańczowa")

# Dodaje tytuł
plt.title("Funkcja rosnąca jest niebieska, malejąca jest poamarańczowa")

# Tworzy legendę położoną na wschód z orientacją poziomą i dwiema kolumnami
legend = plt.legend(loc="right", ncol=2)

# Dostosowuje rozmieszczenie etykiet
plt.subplots_adjust(right=0.85)  # Przesuwa prawą krawędź wykresu w lewo
plt.setp(legend.get_texts(), horizontalalignment='right')  # Ustawia etykiety na prawo

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 6

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(1, 11)  # Wektor od 1 do 10
y1 = x
y2 = np.flip(x)  # Odwraca wektor

# Rysuje dwie linie
plt.plot(x, y1, label="I am blue")
plt.plot(x, y2, label="I am orange")

# Dodaje tytuł
plt.title("Legenda bez swojej ramki")

# Tworzy legendę położoną na wschód bez ramki
plt.legend( loc="right", frameon=False)

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 7

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(1, 11)  # Wektor od 1 do 10
y1 = x
y2 = np.flip(x)  # Odwraca wektor

# Rysuje dwie linie
plt.plot(x, y1, label="Niebieska")
plt.plot(x, y2, label="Pomarańczowa")

# Dodaje tytuł
plt.title("Zmiana kolejności w legendzie")

# Tworzy legendę położoną na wschód
plt.legend( loc="right", markerfirst = False)



plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 8

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(1, 11)  # Wektor od 1 do 10
y1 = x
y2 = np.flip(x)  # Odwraca wektor

# Rysuje dwie linie
plt.plot(x, y1, label="Niebieska")
plt.plot(x, y2, label="Pomarańczowa")

# Dodaje tytuł
plt.title("Zmiana koloru napisów")

# Tworzy legendę położoną na wschód
plt.legend( loc="right", markerfirst = False, labelcolor = 'red')



plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 9

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(1, 11)  # Wektor od 1 do 10
y1 = x
y2 = np.flip(x)  # Odwraca wektor

# Rysuje dwie linie
plt.plot(x, y1, label="Niebieska")
plt.plot(x, y2, label="Pomarańczowa")

# Dodaje tytuł
plt.title("Ukrycie legendy")

# Tworzy legendę położoną na wschód
legend = plt.legend(loc="right", markerfirst=False, labelcolor='red')

# Ukrywa legendę
legend.set_visible(False)

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 10

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 2, 1)  # Wektor od 0 do 1

# Rysuje trzy linie z etykietami w tym samym wywołaniu funkcji plot
plt.plot(x, x, label="Niebieski")
plt.plot(x, 2*x, label="Pomarańczowy")
plt.plot(x, 3*x, label="Zielony")

# Dodaje tytuł
plt.title("Labels are embedded in call to plot\nLegend is hidden and then shown")
# Włącza ramkę wokół legendy
plt.legend(frameon=True)

# Ukrywa legendę
plt.legend().set_visible(False)

# Pokazuje legendę
plt.legend().set_visible(True)

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 11

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 2, 1)  # Wektor od 0 do 1

# Rysuje trzy linie
plt.plot(x, x)
plt.plot(x, 2*x)
plt.plot(x, 3*x)

# Dodaje tytuł z tekstem interpretowanym przez LaTeX
plt.title("Tytuły z literami greckimi")

# Tworzy legendę z tekstem interpretowanym przez LaTeX
plt.legend([r'$\alpha$', r'$\beta=2\alpha$', r'$\gamma=3\alpha$'], loc='best')

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 12

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

# Rysuje dwie linie
plt.plot(x, x)
plt.plot(x, 2*x)

plt.title("Labele bez interpretera TeX (w Pythonie jest on domyślnie wyłączony)")

# Tworzy legendę z interpreterem TeX wyłączonym
plt.legend(["Hello_World", "foo^bar"], loc='best', handlelength=2)

plt.show()  # Wyświetla wykres

# %% [markdown]
# #Zadanie 13

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

labels = []
colororder = plt.rcParams['axes.prop_cycle'].by_key()['color']  # Pobiera domyślny cykl kolorów

for i in range(1, 6):
    h = plt.plot(np.arange(1, 101), i + np.random.rand(100))
    plt.setp(h, color=colororder[i - 1])
    labels.append("Signal " + str(i))

plt.title("Sygnały z losowym przesunięciem i jednorodnym szumem\nLegenda pokazana poniżej i poza wykresem")
plt.xlabel("Nr próbki[k]")
plt.ylabel("Amplituda [V]")

# Tworzy legendę poza wykresem na południu
plt.legend(labels, loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=5)

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 14

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.linspace(0, 10)
plt.plot(x, x)
plt.gca().set_prop_cycle(None)  # Resetuje cykl kolorów

plt.stem(x, x**2, linefmt='g', markerfmt='go', basefmt=' ')
plt.title("Pierwszy stworzony obiekt dostaje pierwszą etykietę")
plt.legend(["liniowy"])

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 15

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.linspace(0, 10)
plt.plot(x, x, label="liniowy")
plt.plot(x, x**2)

plt.title("Pierwszy stworzony obiekt dostaje pierwszą etykietę")
plt.legend()

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 16

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.linspace(0, 10)
plt.plot(x, x, label="liniowy")
plt.plot(x, x**2, label="kwadratowy")

plt.title("Etykiety są dodawane w kolejności tworzenia obiektów")
plt.legend()

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 17

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

rand_3x3_data1 = np.array([[0.341447, 0.171220, 0.284370], [0.039773, 0.731725, 0.779382], [0.2, 0.5, 0.8]])
x = np.arange(3)

width = 0.2  # Szerokość każdego słupka
offset = 0.25  # Przesunięcie dla każdej grupy słupków

bar1 = plt.bar(x - offset, rand_2x3_data1[0], width=width, label="1szy słupek")
bar2 = plt.bar(x, rand_2x3_data1[1], width=width, label="2gi słupek")
bar3 = plt.bar(x + offset, rand_2x3_data1[2], width=width, label="3ci słupek")

plt.ylim(0, 1.0)
plt.title("Funkcja legend() działa dla wykresów słupkowych")

# Tworzy legendę dla każdej grupy słupków
plt.legend([bar1, bar2, bar3], ["1szy słupek", "2gi słupek", "3ci słupek"])

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 18

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

surf = ax.plot_surface(x, y, z, cmap='cool')

# Dodaje legendę za pomocą etykiet
handles = [plt.Line2D([0], [0], color=plt.cm.cool(0.5), lw=4)]
labels = ['peaks()']
ax.legend(handles, labels)

ax.set_title("Funkcja legend() działa także dla obiektów powierzchniowych")

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 19

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

rand_2x3_data2 = np.array([[0.44804, 0.84368, 0.23012], [0.72311, 0.58335, 0.90531]])
x = np.arange(3)

plt.bar(x, rand_2x3_data2[0], label="1szy słupek")
plt.bar(x, rand_2x3_data2[1], bottom=rand_2x3_data2[0], label="2gi słupek")

plt.ylim(0, 1.2)
plt.title('ustawienie napisu w legendzie po lewej stronie')

# Ustawia legendę z kolorami po lewej stronie etykiet
plt.legend(["1szy słupek", "2gi słupek"], markerfirst=False, loc='upper right')

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 20

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 7, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x**2 / 10)
y4 = np.cos(x**2 / 10)

# Rysuje wszystkie funkcje
h = plt.plot(x, y1, x, y2, x, y3, x, y4)

plt.title("Tylko obiekty sin() mają etykiety")
# Tworzy legendę tylko dla obiektów sin()
plt.legend([h[0], h[2]], ["sin(x)", "sin(x^2/10)"], loc="lower left")

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 21

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 10, 0.1)

# Rysuje sin(x) z etykietą "sin (x)"
plt.plot(x, np.sin(x), label="sin (x)")
# Rysuje cos(x) z etykietą "cos (x)"
plt.plot(x, np.cos(x), label="cos (x)")

plt.title("Legenda skonstruowana z wielu wywołań funkcji plot")
plt.legend()

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 22

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 10, 0.1)

# Rysuje sin(x) z etykietą "Sine"
plt.plot(x, np.sin(x), label="Sine")
# Rysuje cos(x) z etykietą "Cosine"
plt.plot(x, np.cos(x), label="Cosine")

plt.title("Określony tekst etykiety zastępuje poprzednie etykiety")
plt.legend(loc="upper right")

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 23

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 11)

# Tworzy 10 różnych funkcji z losowymi danymi
for i in range(10):
    y = np.random.rand(11)
    plt.plot(x, y, label=f'Function {i+1}')


plt.plot(x, y)

plt.xlabel("Indeksy")
plt.ylabel("Losowe wartości")
plt.title('legend().remove() usuwa legendę')

# Tworzy legendę
plt.legend(list(map(str, range(0, 11))), loc="upper right", title="Legenda")


# Usuwa legendę
plt.legend().remove()

plt.axis([0, 10, 0, 1])

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 24

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(1, 6)

# Tworzy subploty
plt.subplot(2, 2, 1)
plt.plot(x, np.random.rand(len(x)), color='blue')
plt.legend(list(map(str, x)), loc="upper left", bbox_to_anchor=(1.05, 1))

plt.subplot(2, 2, 2)
plt.plot(x, np.random.rand(len(x)), color='green')
plt.legend(list(map(str, x)), loc="upper right", bbox_to_anchor=(1.05, 1))

plt.subplot(2, 2, 3)
plt.plot(x, np.random.rand(len(x)), color='red')
plt.legend(list(map(str, x)), loc="lower left", bbox_to_anchor=(1.05, 1))

plt.subplot(2, 2, 4)
plt.plot(x, np.random.rand(len(x)), color='purple')
plt.legend(list(map(str, x)), loc="lower right", bbox_to_anchor=(1.05, 1))

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 25

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

# Rysuje losowy wykres
plt.plot(np.random.rand(2))

plt.title("Funkcja legend() powinna ostrzec, jeśli podano dodatkowe etykiety") # Jednak w przypadku kodu w Python, występuje brak ostrzeżenia

# Tworzy legendę z dodatkowymi etykietami
plt.legend(["Hello", "World", "interpreter", "foobar"])

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 26

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 11)
y1 = np.random.rand(len(x))
y2 = np.random.rand(len(x))+2

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()  # Tworzy drugą oś y

# Rysuje obie linie na odpowiednich osiach y
ax1.plot(x, y1, 'b-')
ax2.plot(x, y2, 'r-')

# Ustawia kolor osi y
ax1.tick_params(axis='y', colors='blue')
ax2.tick_params(axis='y', colors='red')


# Dodaje legendę z dwoma etykietami
ax1.legend(["Blue"], loc="lower left")
ax2.legend(["Red"], loc="lower right")

plt.title("Dwie różne osie y")
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 27

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 11)
y1 = np.random.rand(len(x))
y2 = np.random.rand(len(x))+3

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()  # Tworzy drugą oś y

# Rysuje obie linie na odpowiednich osiach y
ax1.plot(x, y1, 'b-')
ax2.plot(x, y2, 'r-')

# Ustawia kolor osi y
ax1.tick_params(axis='y', colors='blue')
ax2.tick_params(axis='y', colors='red')


# Dodaje legendę z dwoma etykietami
ax1.legend(["Blue"], loc="lower left")
ax2.legend(["Red"], loc="lower right")

plt.title("Dwie różne osie y")
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 28

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

x = np.arange(0, 11)
y1 = np.random.rand(len(x))
y2 = np.random.rand(len(x))-1

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()  # Tworzy drugą oś y

# Rysuje obie linie na odpowiednich osiach y
ax1.plot(x, y1, 'b-')
ax2.plot(x, y2, 'r-')

# Ustawia kolor osi y
ax1.tick_params(axis='y', colors='blue')
ax2.tick_params(axis='y', colors='red')


# Dodaje legendę z dwoma etykietami
ax1.legend(["Blue"], loc="lower left")
ax2.legend(["Red"], loc="lower right")

plt.title("Dwie różne osie y")
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 29

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

# Rysuje linię
plt.plot(np.arange(1, 11), np.arange(1, 11))

# Dodaje tytuł
plt.title("Bardzo długa etykieta może czasami sprawiać problemy")

# Dodaje legendę z długą etykietą i umieszcza ją poza obszarem wykresu
plt.legend(["hello very very very very very very very very very very big world"], loc="upper left", bbox_to_anchor=(1, 1))

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 30

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

option = "right"

# Tworzy subploty
plt.subplot(3, 1, 1)
plt.plot(np.random.rand(4))
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.title("Subploty ustawiające legendę po prawej")
plt.legend(["1"], loc="upper right", bbox_to_anchor=(1.25, 1))
plt.legend([option], loc="upper right", bbox_to_anchor=(1.25, 1))

plt.subplot(3, 1, 2)
plt.plot(np.random.rand(4))
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.legend(["1234567890"], loc="right", bbox_to_anchor=(1.25, 0.5))
plt.legend([option], loc="upper right", bbox_to_anchor=(1.25, 1))

plt.subplot(3, 1, 3)
plt.plot(np.random.rand(4))
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.legend(["12345678901234567890"], loc="lower right", bbox_to_anchor=(1.25, 0))
plt.legend([option], loc="upper right", bbox_to_anchor=(1.25, 1))

plt.tight_layout()  # Dopasowuje subploty, aby zmieściły się w oknie
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 31

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

option = "left"  # Zmiana położenia legendy na lewą stronę

# Tworzy subploty
plt.subplot(3, 1, 1)
plt.plot(np.random.rand(4))
plt.title("Subploty ustawiające legendę po lewej")
plt.legend(["1"], loc="upper right", bbox_to_anchor=(1.05, 1))
plt.legend([option], loc="upper left", bbox_to_anchor=(-0.15, 1))  # Przesunięcie w lewo

plt.subplot(3, 1, 2)
plt.plot(np.random.rand(4))
plt.legend(["1234567890"], loc="upper right", bbox_to_anchor=(1.05, 1))
plt.legend([option], loc="upper left", bbox_to_anchor=(-0.15, 1))  # Przesunięcie w lewo

plt.subplot(3, 1, 3)
plt.plot(np.random.rand(4))
plt.legend(["12345678901234567890"], loc="upper right", bbox_to_anchor=(1.05, 1))
plt.legend([option], loc="upper left", bbox_to_anchor=(-0.15, 1))  # Przesunięcie w lewo

plt.tight_layout()  # Dopasowuje subploty, aby zmieściły się w oknie
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 32

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

option = "right"

# Tworzy subploty
fig, axs = plt.subplots(3, 1, figsize=(6, 8))

for ax in axs:
    ax.plot(np.random.rand(4))
    ax.set_xlabel("xlabel")
    ax.set_ylabel("ylabel")
    ax.yaxis.set_ticks_position(option)  # Przesuwa oznaczenia osi Y na prawo
    ax.yaxis.set_label_position(option)  # Przesuwa etykietę osi Y na prawo
    ax.legend(["1"], loc="upper left", bbox_to_anchor=(1.05, 1))
    ax.legend([option], loc="upper left", bbox_to_anchor=(1.05, 1))

plt.tight_layout()  # Dopasowuje subploty, aby zmieściły się w oknie
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 33

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

option = "right"

# Tworzy subploty
fig, axs = plt.subplots(3, 1, figsize=(6, 8))

for ax in axs:
    ax.plot(np.random.rand(4))
    ax.set_xlabel("xlabel")
    ax.set_ylabel("ylabel")
    ax.yaxis.set_ticks_position(option)  # Przesuwa oznaczenia osi Y na lewo
    ax.yaxis.set_label_position(option)  # Przesuwa etykietę osi Y na lewo
    ax.legend(["12345678901234567890"], loc="upper right", bbox_to_anchor=(1.05, 1))
    ax.legend([option], loc="upper left", bbox_to_anchor=(-0.3, 1))  # Przesunięcie w lewo

plt.tight_layout()  # Dopasowuje subploty, aby zmieściły się w oknie
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 34

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

option = "left"

# Tworzy subploty
fig, axs = plt.subplots(3, 1, figsize=(6, 8))

for ax in axs:
    ax.plot(np.random.rand(4))
    ax.set_xlabel("xlabel")
    ax.set_ylabel("ylabel")
    ax.xaxis.set_ticks_position("top")  # Przesuwa oznaczenia osi X na górę
    ax.xaxis.set_label_position("top")  # Przesuwa etykietę osi X na górę
    ax.yaxis.set_ticks_position(option)  # Przesuwa oznaczenia osi Y na lewo
    ax.yaxis.set_label_position(option)  # Przesuwa etykietę osi Y na lewo
    ax.legend(["12345678901234567890"], loc="upper right", bbox_to_anchor=(1.05, 1))
    ax.legend([option], loc="upper left", bbox_to_anchor=(-0.3, 1))  # Przesunięcie w lewo

plt.tight_layout()  # Dopasowuje subploty, aby zmieściły się w oknie
plt.show()  # Wyświetla wykres

# %% [markdown]
# # Zadanie 35

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()  # Czyści aktualny wykres, jeśli istnieje

# Rysuje wykres
plt.plot(range(1, 11))

# Dodaje legendę
plt.legend(["Legend Text"])

# Ustawia tytuł
plt.title("\n".join(["Multi-line", "titles", "are a", "problem", "See bug #39697"]))

plt.show()  # Wyświetla wykres

# %% [markdown]
# # Raport
# Podczas tego eksperymentu przetestowaliśmy różne aspekty funkcji legend() w środowisku Python. Wykorzystując różne przykłady, eksplorowaliśmy możliwości modyfikacji etykiet w legendzie, zarówno pod względem treści, jak i ich rozmieszczenia na wykresie. Rozpoczęliśmy od prostych modyfikacji, takich jak zmiana tytułu wykresu na polski oraz przetłumaczenie napisów w legendzie. Następnie eksperymentowaliśmy z dodawaniem legendy do różnych rodzajów wykresów, w tym wykresów liniowych, słupkowych i powierzchniowych.
#
# W przypadku wykresów liniowych sprawdziliśmy, jak działa funkcja legend() w różnych sytuacjach, takich jak umieszczanie legendy na różnych pozycjach na wykresie oraz wybór konkretnych obiektów do uwzględnienia w legendzie. W przypadku wykresów słupkowych zastosowaliśmy różne techniki, aby dostosować legendę do naszych potrzeb, na przykład zmieniając położenie legendy i definiując etykiety w sposób dynamiczny.
#
# Kolejno, przetestowaliśmy funkcję plotyy(), która pozwala na tworzenie wykresów z dwoma osiami y. Tutaj również eksperymentowaliśmy z dodawaniem legendy, uwzględniając specyfikę tego typu wykresów. Na koniec, zwróciliśmy uwagę na różne aspekty wizualne, takie jak zmiana kolorów i stylów linii, oraz wpływ długich etykiet na wygląd legendy.
#
# Nasze eksperymenty pokazały, że funkcja legend() w środowisku Python oferuje szeroki zakres możliwości konfiguracji legendy na wykresie, co pozwala dostosować ją do potrzeb użytkownika i poprawić czytelność prezentowanych danych.
#
# W trakcie eksperymentów z funkcją legend() w środowisku Python odkryliśmy wiele cennych informacji na temat sposobów dostosowania legendy do różnych rodzajów wykresów oraz preferencji użytkownika. Przetestowaliśmy różne opcje, takie jak zmiana położenia legendy, definiowanie własnych etykiet, czy nawet manipulowanie interakcjami pomiędzy legendą a innymi elementami wykresu.
#
# Ważną kwestią, na którą natknęliśmy się podczas eksperymentów, jest również wpływ długości etykiet na czytelność legendy. Długie etykiety mogą czasami powodować przesłonięcie innych elementów wykresu lub sprawić, że legenda stanie się trudna do odczytania. Dlatego ważne jest, aby zachować umiar i stosować krótkie, zwięzłe etykiety, które jednocześnie dobrze opisują prezentowane dane.
#
# W naszych testach zwróciliśmy również uwagę na elastyczność funkcji legend() oraz jej zdolność do obsługi różnych typów wykresów i sytuacji. Dzięki temu użytkownicy mogą łatwo dostosować legendę do swoich potrzeb, niezależnie od tego, czy tworzą proste wykresy liniowe, czy bardziej zaawansowane wykresy z dwoma osiami y.
